# %% [markdown]
# # 課題内容
#
# 以下に示す文脈自由文法と記号列について、解析木を作ってください。
#
# ### 1. 文法と記号列
# - **文法**: $S \to 0S1 \mid 01$
# - **記号列**: $000111$
#
# ### 2. 文法と記号列
# - **文法**: $S \to +SS \mid *SS \mid a$
# - **記号列**: $+*aaa$
#
# ---
#
# ### 提出要件
# - **形式**: WordやGoogle DocumentsなどでA4サイズのレポートを作成し、**PDFファイル形式**で提出すること。
# - **締切**: 12/07 23:59
# - **備考**: 締切超過後の提出も、減点の上一定の加点をする。
